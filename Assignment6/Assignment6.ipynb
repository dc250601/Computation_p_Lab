# %%
import math
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
import library
import os
# Out:
# C:\Users\cdipt\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\cdipt\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\cdipt\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\cdipt\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Question 1

# %%
def dvdt(x,v,t = None,w=1.2,gamma=0.2):
    return (math.cos(w*t) - x - (gamma*v)/2)

def dxdt(v,x=None,t=None):
    return v

# %%
x,v,t = library.differential_equation.Solution_Runge_Kutta_4(dxdt=dxdt,
                                                             dvdt=dvdt,
                                                             init_value=(2,-1),
                                                             range_=(0,200))

# %%
plt.figure(figsize=(12,6))
plt.plot(t,x)

# %% [markdown]
# ### Question 2

# %%
L0 =0
Ln = 10
T0 = 40
Tn = 200
Ta = 20
guess =8
def dvdt(x,v,t,w=1,neu=0.15):
    return  - 0.01*(Ta-x)
def dxdt(v,t):
    return v

# %%
y,_,x =library.differential_equation.Solution_Shooting_Runge_Kutta_4(dxdt,dvdt,L0,Ln,T0,Tn,guess)

# %%
#Finding the temperature closest to T =100
closest = 1e300
index = 0
for i in range(len(y)):
    if abs(y[i]-100)<closest:
        index = i
        closest = abs(y[i]-100)

# %%
print("The value fo x at which T is 100 is",x[index])
# Out:
# The value fo x at which T is 100 is 4.42999999999995

# %% [markdown]
# ### Question 3

# %%
def func(x):
    if x == 1:
        val = 300
    else:
        val = 0
    return val

# %%
steps =[0,10,20,50,100,200,500,1000]
plt.figure(figsize=(12,6))
for step in steps:
    x,y = library.differential_equation.Solution_Partial_Differential_Explicit_Euler(steps=step,
                                                                           init_func=func)
    plt.plot(x,y, label = f"{step}")
plt.legend()

# %% [markdown]
# ### Question 4

# %%
guess = library.matrix.matrix([[1],[2],[3]])
mat = library.matrix.matrix([[2,1,2],
                      [2,2,-2],
                      [3,1,1]])

# %%
eigen_vector,eigen_value,iterations = library.Eigen_Value_Power_Iteration(guess=guess,matrix=mat,eps = 1e-3,MAX_ITER = 10000)

# %%
print(" The eigen_vector")
print(eigen_vector)
print("-"*30)
print("The eigen value")
print(eigen_value)
print("-"*30)
print("Number of iterations ")
print(iterations)
# Out:
#  The eigen_vector
#  0.7071020714404481
#  0.0007736740221867499
#  0.7071110676500084
#
# ------------------------------
# The eigen value
# 4.00013987614603
# ------------------------------
# Number of iterations
# 7
